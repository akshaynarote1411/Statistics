# %%
# Euclidean_dist = sqrt(square(x2-x1)+square(y2-y1))


a = [10,20]
b = [30,40]

x1 = a[0]
y1 = a[1]
x2 = b[0]
y2 = b[1]

import numpy as np

d = np.sqrt(np.square(b[0]-a[0])+np.square(b[1]-a[1]))
d
# Out:
# np.float64(28.284271247461902)

# %%
arr1 = np.array(x)
arr2 = np.array(y)

from numpy.linalg import norm  

d = norm(arr1-arr2)
d
# Out:
# np.float64(28.284271247461902)
