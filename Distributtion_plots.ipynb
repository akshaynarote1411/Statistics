# %% [raw]
# # Q. How to create class Intervals
#
#
# Assume that there are 80 obserservations are there
# so, number of classes = 2^k >= 80
#
# k      2^k
#
# 1       2
# 2       4
# 3       8
# 4       16
# 5       32
# 6       64
# 7       128
# .        .
# .        .
# .        .
# k        2^k
#
#
# so, number of class intervals = 7, because the obseravtaions exits between 64 & 128.
#
#
#
#
# width of intervals = (max - min)/7
#                    = (35-15)/7
#                    = 20/7
#                    ~=3

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({"Names":["sai","varun","tej","riya","priya","jay","raj","ira","nai","bib"],"Marks":[45,54,66,88,98,90,99,35,30,56]})
df
# Out:
#    Names  Marks
# 0    sai     45
# 1  varun     54
# 2    tej     66
# 3   riya     88
# 4  priya     98
# 5    jay     90
# 6    raj     99
# 7    ira     35
# 8    nai     30
# 9    bib     56

# %%
# No. of intervals = (99-30)/10
#                  = 69/10
#                  ~= 7




import matplotlib.pyplot as plt
plt.hist(x=df["Marks"],bins=7)
plt.show()
